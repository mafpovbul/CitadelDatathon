# %%
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as uReq
import requests

# %%
url = 'https://www.premierleague.com/tables?co=1&se=274&ha=-1'
page = requests.get(url, headers={'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.47 Safari/537.36'})

#html parsing
page_soup = soup(page.content, "html.parser")
page_soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="Premier League Table, Form Guide &amp; Season Archives" name="twitter:title"/>
# <meta content="Premier League, Football, Soccer, Official" name="keywords"/>
# <meta content="website" property="og:type"/>
# <meta content="View the latest Premier League tables, form guides and season archives, on the official website of the Premier League." name="description"/>
# <meta content="View the latest Premier League tables, form guides and season archives, on the official website of the Premier League." name="twitter:description"/>
# <meta content="https://s3.amazonaws.com/premierleague-static-files/premierleague/pl_icon.png" name="twitter:image"/>
# <meta content="Premier League Table, Form Guide &amp; Season Archives" property="og:title"/>
# <meta content="https://s3.amazonaws.com/premierleague-static-files/premierleague/pl_icon.png" property="og:image"/>
# <meta content="#38003C" name="theme-color"/>
# ...

# %%
names_containers = page_soup.find_all('span', class_ = "value")
names_containers
# Out:
# [<span class="value">1</span>,
#  <span class="value">2</span>,
#  <span class="value">3</span>,
#  <span class="value">4</span>,
#  <span class="value">5</span>,
#  <span class="value">6</span>,
#  <span class="value">7</span>,
#  <span class="value">8</span>,
#  <span class="value">9</span>,
#  <span class="value">10</span>,
#  <span class="value">11</span>,
#  <span class="value">12</span>,
#  <span class="value">13</span>,
#  <span class="value">14</span>,
#  <span class="value">15</span>,
#  <span class="value">16</span>,
#  <span class="value">17</span>,
#  <span class="value">18</span>,
#  <span class="value">19</span>,
#  <span class="value">20</span>,
#  <span class="value">1</span>,
#  <span class="value">2</span>,
#  <span class="value">3</span>,
#  <span class="value">4</span>,
#  <span class="value">5</span>,
#  <span class="value">6</span>,
#  <span class="value">7</span>,
#  <span class="value">8</span>,
#  <span class="value">9</span>,
# ...

# %%
names_containers = page_soup.find_all('td', class_ = "team")
names_containers[1]
# Out:
# <td class="team" scope="row">
# <a href="/clubs/12/Manchester-United/overview">
# <span class="badge badge-image-container" data-size="25" data-widget="club-badge-image">
# <img class="badge-image badge-image--25" src="https://resources.premierleague.com/premierleague/badges/25/t1.png" srcset="https://resources.premierleague.com/premierleague/badges/25/t1@x2.png 2x"/>
# </span>
# <span class="long">Manchester United</span>
# <span class="short">MUN</span>
# </a>
# </td>

# %%
pos_containers = page_soup.find_all('td', class_ = "pos-transfer-cell")
print(len(pos_containers))
pos_containers[0].text
# Out:
# 713
# 'Centre-Forward'

# %%
value_containers = page_soup.find_all('td', class_ = "rechts mw-transfer-cell")
print(len(value_containers))
value_containers[0].text
if value_containers[1].text[-1] == '.':
    print("x")
# Out:
# 713
# x

# %%
club_containers = page_soup.find_all('td', class_ = "no-border-links verein-flagge-transfer-cell")
print(len(club_containers))
club_containers[0].a.text
# Out:
# 713
# 'E. Frankfurt'

# %%
fee_containers = page_soup.find_all('td', class_ = "rechts bg_blau_20")
print(len(fee_containers))
fee_containers[0].a.text
# Out:
# 157
# '€4.00m'

# %%
club_containers = page_soup.find_all('div', class_ = "table-header")
print(len(club_containers))
club_containers[1]
# Out:
# 19
# <div class="table-header" id="to-2282"><a class="vereinprofil_tooltip" href="/fc-brugge/transfers/verein/2282/saison_id/2020" id="2282"><img alt="Club Brugge KV" class="" src="https://tmssl.akamaized.net/images/wappen/small/2282.png?lm=1448474251" title=" "/></a><h2><a class="vereinprofil_tooltip" href="/fc-brugge/transfers/verein/2282/saison_id/2020" id="2282">Club Brugge KV</a></h2></div>
